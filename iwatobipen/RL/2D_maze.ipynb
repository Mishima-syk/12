# %% [markdown]
# ### Treasure hunter in 2D

# %%
import numpy as np
import pandas as pd
import time
import pprint
import copy
np.random.seed(794)

# %%
N_SIZE = 4
N_STATES = 16  # 4 x 4 2D world
STATE_index = [[i, j] for i in range(4) for j in range(4)]
ACTIONS = ['u', 'd', 'l', 'r']  # up, down, left, right
EPSILON = 0.9  # for greedy
ALPHA = 0.1  # LEARNING RATE
GAMMA = 0.9  # DISCOUNT FACTOR
MAX_EPISODES = 20
FRESH_TIME = 0.1
# P: you!, F: floor, W: Wall, T: treasure , 
# MAZE[0][0] is starting point, MAZE[3][3] is terminal
x0, y0 = 0, 0
MAZE = [  "FFFW", 
                 "FWFF",
                 "FFWW",
                 "FFFT"]
MAZE_LIST = []
for row in MAZE:
    l = [col for col in row]
    MAZE_LIST.append(l)
MAZE_LIST[1][0]
# Out:
# 'F'

# %%
pprint.pprint(STATE_index)
# Out:
# [[0, 0],
#  [0, 1],
#  [0, 2],
#  [0, 3],
#  [1, 0],
#  [1, 1],
#  [1, 2],
#  [1, 3],
#  [2, 0],
#  [2, 1],
#  [2, 2],
#  [2, 3],
#  [3, 0],
#  [3, 1],
#  [3, 2],
#  [3, 3]]

# %%
def build_Q_table(n_states, actions):
    table = pd.DataFrame(np.zeros((n_states, len(actions))), columns=actions)
    return table

def choose_action(state, q_table):
    state_actions = q_table.iloc[state,:]
    if (np.random.uniform() > EPSILON) or (state_actions.all()==0):
        action_name = np.random.choice(ACTIONS)
        # print(action_name)
        # print("random action {}".format(action_name))
    else:
        action_name = state_actions.argmax()
        # print("random greedy {}".format(action_name))
    return action_name

def move_check(x, y):
    if x > 3 or x < 0 or y > 3 or y < 0:  # illegal !
        return True
    else:
        pass

def get_env_feedback(S, A):
    # The argent can get rewards when Agent could arrive at Terminal.
    x,y = STATE_index[S]
    if A == 'u':
        x_, y_ = x - 1, y + 0  # UP
        if MAZE_LIST[x][y] == "T":
            S_ = 'terminal'
            R = 1
        elif move_check(x_, y_):
            S_ = STATE_index.index([x,y])
            R = -1
        elif MAZE_LIST[x_][y_] == "W": # OUCH
            S_ = STATE_index.index([x,y])
            R = -1
        else:
            S_ = STATE_index.index([x_,y_])
            R = 0
        return S_, R

    if A == 'd':
        x_, y_ = x + 1, y + 0  # DOWN
        if MAZE_LIST[x][y] == "T":
            S_ = 'terminal'
            R = 1
        elif move_check(x_, y_):
            S_ = STATE_index.index([x,y])
            R = -1
        elif MAZE_LIST[x_][y_] == "W": # OUCH
            S_ = STATE_index.index([x,y])
            R = -1
        else:
            S_ = STATE_index.index([x_,y_])
            R = 0
        return S_, R
 
    if A == 'l':
        x_, y_ = x + 0, y - 1  # LEFT
        if move_check(x_, y_):
            S_ = STATE_index.index([x,y])
            R = -1
        elif MAZE_LIST[x][y] == "T":
            S_ = 'terminal'
            R = 1
        elif MAZE_LIST[x_][y_] == "W": # OUCH
            S_ = STATE_index.index([x,y])
            R = -1
        else:
            S_ = STATE_index.index([x_,y_])
            R = 0
        return S_, R

    if A == 'r':
        x_, y_ = x + 0, y + 1  # RIGHT
        if move_check(x_, y_):
            S_ = STATE_index.index([x,y])
            R = -1
        elif MAZE_LIST[x][y] == "T":
            S_ = 'terminal'
            R = 1
        elif MAZE_LIST[x_][y_] == "W":  # OUCH
            S_ = STATE_index.index([x,y])
            R = -1
        else:
            S_ = STATE_index.index([x_,y_])
            R = 0
        return S_, R

def update_env(S, episode, step_counter):
    env = MAZE_LIST
    if S == 'terminal':
        interaction = 'Episode {}: total steps {}'.format(episode, step_counter)
        print('\r{}'.format(interaction), end=' ')
        time.sleep(2)
        print('\r                                          ', end=' ')
    else:
        new_env = copy.deepcopy(env)
        x, y = STATE_index[S]
        new_env[x][y] = "P"
        pprint.pprint("{}: steps".format(step_counter))
        pprint.pprint(new_env)
        time.sleep(FRESH_TIME)

# %%
def rlQlearn():
    q_table = build_Q_table(N_STATES, ACTIONS)
    for episode in range(MAX_EPISODES):
        step_counter = 0
        S = 0
        is_terminated = False
        update_env(S, episode, step_counter)
        while not is_terminated:
            A = choose_action(S, q_table)
            S_, R = get_env_feedback(S, A)
            q_predict = q_table.loc[S, A]
            if S_ != 'terminal':
                q_target = R + GAMMA * q_table.iloc[S_, :].max()
                #print(q_target)
            else:
                q_target = R
                is_terminated = True
            # print( q_target, q_predict, R)
            q_table.loc[S, A] += ALPHA * (q_target - q_predict)
            S = S_
            step_counter += 1
            update_env(S, episode, step_counter)
    return q_table

def rlSARSA():
    q_table = build_Q_table(N_STATES, ACTIONS)
    for episode in range(MAX_EPISODES):
        step_counter = 0
        S = 0
        is_terminated = False
        update_env(S, episode, step_counter)
        while not is_terminated:
            A = choose_action(S, q_table)
            S_, R = get_env_feedback(S, A)
            q_predict = q_table.loc[S, A]
            if S_ != 'terminal':
                A_ = choose_action(S, q_table)
                q_target = R + GAMMA * q_table.loc[S_, A_]
                #print(q_target)
            else:
                q_target = R
                is_terminated = True
            #print( q_target, q_predict, R)
            q_table.loc[S, A] += ALPHA * (q_target - q_predict)
            S = S_
            step_counter += 1
            update_env(S, episode, step_counter)
    return q_table

# %%
q_table = rlQlearn()
# Out:
# '0: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '1: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '2: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '3: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '4: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '5: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '6: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '7: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '8: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '9: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '10: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '11: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '12: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '13: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '14: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '15: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '16: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '17: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '18: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '19: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '20: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '21: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '22: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '23: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '24: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '25: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '26: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '27: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '28: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '29: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '30: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '31: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '32: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '33: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '34: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '35: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '36: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '37: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '38: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '39: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '40: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '41: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '42: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '43: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '44: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '45: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '46: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '47: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '48: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '49: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '50: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '51: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '52: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '53: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '54: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '55: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '56: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '57: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '58: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '59: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '60: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '61: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '62: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '63: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '64: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '65: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '66: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '67: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'P'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '68: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'P', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '69: steps'
# [['F', 'F', 'P', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '70: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '71: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '72: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '73: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '74: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '75: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '76: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '77: steps'
# [['F', 'P', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '78: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '79: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '80: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '81: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '82: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '83: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '84: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '85: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '86: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '87: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '88: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '89: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '90: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '91: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '92: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '93: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '94: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '95: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['P', 'F', 'F', 'T']]
# '96: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'P', 'F', 'T']]
# '97: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '98: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '99: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '100: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '101: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '102: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '103: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['P', 'F', 'F', 'T']]
# '104: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '105: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '106: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '107: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '108: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '109: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '110: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '111: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '112: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '113: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '114: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '115: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '116: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '117: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '118: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '119: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '120: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['P', 'F', 'F', 'T']]
# '121: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '122: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '123: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '124: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['P', 'F', 'F', 'T']]
# '125: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['P', 'F', 'F', 'T']]
# '126: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '127: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '128: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '129: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '130: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '131: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '132: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '133: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '134: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '135: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '136: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '137: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
#
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'P']]
# '7: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'P']]
#                                            '0: steps'
# [['P', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '1: steps'
# [['F', 'F', 'F', 'W'],
#  ['P', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '2: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['P', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '3: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'P', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]
# '4: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'P', 'F', 'T']]
# '5: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'P', 'T']]
# '6: steps'
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'P']]

# %%
q_table
# Out:
#                u         d             l             r
# 0  -6.861894e-01  0.001060 -7.941089e-01  4.304672e-10
# 1  -8.499054e-01 -0.794109  9.087641e-09  3.874205e-11
# 2  -6.513216e-01  0.000000  8.178877e-10 -8.499054e-01
# 3   0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# 4   4.782969e-09  0.004956 -7.940923e-01 -7.940082e-01
# 5   0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# 6   0.000000e+00 -0.833228 -7.941089e-01  0.000000e+00
# 7  -8.499054e-01 -0.717570  0.000000e+00 -8.146980e-01
# 8   1.943770e-04  0.000046 -6.861640e-01  1.878593e-02
# 9  -2.709934e-01  0.061444  1.900732e-04 -2.710000e-01
# 10  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# 11  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# 12  2.483802e-05 -0.343900 -4.095100e-01  5.124870e-04
# 13  3.296032e-03 -0.468047  6.561000e-06  1.535763e-01
# 14 -5.837604e-01 -0.586073  7.775514e-04  3.292640e-01
# 15  4.095100e-01  0.612580  4.685590e-01 -5.304672e-02

# %%
q_table['location'] = STATE_index

# %%
for i, row in enumerate(q_table[['u','d','l','r']].idxmax(axis=1)):
    print( STATE_index[i], row )
# Out:
# [0, 0] d
# [0, 1] l
# [0, 2] l
# [0, 3] u
# [1, 0] d
# [1, 1] u
# [1, 2] u
# [1, 3] l
# [2, 0] r
# [2, 1] d
# [2, 2] u
# [2, 3] u
# [3, 0] r
# [3, 1] r
# [3, 2] r
# [3, 3] d

# %%
MAZE_LIST
# Out:
# [['F', 'F', 'F', 'W'],
#  ['F', 'W', 'F', 'F'],
#  ['F', 'F', 'W', 'W'],
#  ['F', 'F', 'F', 'T']]

# %%
q_table
# Out:
#                u         d             l             r location
# 0  -6.861894e-01  0.001060 -7.941089e-01  4.304672e-10   [0, 0]
# 1  -8.499054e-01 -0.794109  9.087641e-09  3.874205e-11   [0, 1]
# 2  -6.513216e-01  0.000000  8.178877e-10 -8.499054e-01   [0, 2]
# 3   0.000000e+00  0.000000  0.000000e+00  0.000000e+00   [0, 3]
# 4   4.782969e-09  0.004956 -7.940923e-01 -7.940082e-01   [1, 0]
# 5   0.000000e+00  0.000000  0.000000e+00  0.000000e+00   [1, 1]
# 6   0.000000e+00 -0.833228 -7.941089e-01  0.000000e+00   [1, 2]
# 7  -8.499054e-01 -0.717570  0.000000e+00 -8.146980e-01   [1, 3]
# 8   1.943770e-04  0.000046 -6.861640e-01  1.878593e-02   [2, 0]
# 9  -2.709934e-01  0.061444  1.900732e-04 -2.710000e-01   [2, 1]
# 10  0.000000e+00  0.000000  0.000000e+00  0.000000e+00   [2, 2]
# 11  0.000000e+00  0.000000  0.000000e+00  0.000000e+00   [2, 3]
# 12  2.483802e-05 -0.343900 -4.095100e-01  5.124870e-04   [3, 0]
# 13  3.296032e-03 -0.468047  6.561000e-06  1.535763e-01   [3, 1]
# 14 -5.837604e-01 -0.586073  7.775514e-04  3.292640e-01   [3, 2]
# 15  4.095100e-01  0.612580  4.685590e-01 -5.304672e-02   [3, 3]
